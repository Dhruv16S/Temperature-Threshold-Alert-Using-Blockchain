# %%
import pandas as pd

# %%
data = pd.read_csv("./data.csv")
data
# Out:
#           TAGNAME              TIME  SUNANGLE  VALUE  Latitude  Longitude  \
# 0      Main optic  30-06-2023 23:01 -5.540028    1.0    59.998     -1.159
# 1           Light  30-06-2023 22:28 -2.744051    1.0    59.122     -5.816
# 2      Optic Main  30-06-2023 22:23 -2.809405    1.0    59.854     -1.276
# 3      Optic Main  30-06-2023 22:02 -1.964771    1.0    59.390     -2.382
# 4      Main Optic  30-06-2023 22:02 -1.404698    1.0    60.741     -0.795
# ...           ...               ...       ...    ...       ...        ...
# 13643         NaN               NaN       NaN    NaN       NaN        NaN
# 13644         NaN               NaN       NaN    NaN       NaN        NaN
# 13645         NaN               NaN       NaN    NaN       NaN        NaN
# 13646         NaN               NaN       NaN    NaN       NaN        NaN
# 13647         NaN               NaN       NaN    NaN       NaN        NaN
#
#          Temp 2m  Dewpoint 2m     Pressure  Precipitation  GHI  DHI  BNI  \
# ...

# %%
print("Dataset information")
data.info()
# Out:
# Dataset information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13648 entries, 0 to 13647
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TAGNAME        1032 non-null   object
#  1   TIME           1032 non-null   object
#  2   SUNANGLE       1032 non-null   float64
#  3   VALUE          1032 non-null   float64
#  4   Latitude       1032 non-null   float64
#  5   Longitude      1032 non-null   float64
#  6   Temp 2m        1032 non-null   float64
#  7   Dewpoint 2m    1032 non-null   float64
#  8   Pressure       1032 non-null   float64
#  9   Precipitation  1032 non-null   float64
#  10  GHI            1032 non-null   float64
#  11  DHI            1032 non-null   float64
#  12  BNI            1032 non-null   float64
#  13  Location       1032 non-null   object
#  14  Date           1032 non-null   object
#  15  Time           1032 non-null   object
# ...

# %%
print("Dataset with location as Balta Sound")
filtered_data = data[data["Location"] == "Balta_Sound"]
filtered_data.to_csv("./filtered_data_balta_sound.csv", index = False)
filtered_data
# Out:
# Dataset with location as Balta Sound
#          TAGNAME              TIME   SUNANGLE  VALUE  Latitude  Longitude  \
# 4     Main Optic  30-06-2023 22:02  -1.404698    1.0    60.741     -0.795
# 29    Main Optic  30-06-2023 02:59   1.235129    0.0    60.741     -0.795
# 34    Main Optic  29-06-2023 21:38  -0.232289    1.0    60.741     -0.795
# 57    Main Optic  29-06-2023 04:00   6.361275    0.0    60.741     -0.795
# 66    Main Optic  28-06-2023 21:23   0.688343    1.0    60.741     -0.795
# 95    Main Optic  28-06-2023 03:20   2.977769    0.0    60.741     -0.795
# 101   Main Optic  27-06-2023 21:54  -0.972598    1.0    60.741     -0.795
# 149   Main Optic  27-06-2023 03:41   4.726289    0.0    60.741     -0.795
# 159   Main Optic  26-06-2023 21:50  -0.802578    1.0    60.741     -0.795
# 181   Main Optic  26-06-2023 02:59   1.471106    0.0    60.741     -0.795
# 188   Main Optic  25-06-2023 21:36  -0.060105    1.0    60.741     -0.795
# ...

# %%
print("Data gathered only for the month of June")
filtered_data = filtered_data[filtered_data["Date"] >= "01-06-2023 00:00"]
# Out:
# Data gathered only for the month of June

# %%
print("Filtered Data Details")
filtered_data.info()
# Out:
# Filtered Data Details
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 4 to 1025
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TAGNAME        60 non-null     object
#  1   TIME           60 non-null     object
#  2   SUNANGLE       60 non-null     float64
#  3   VALUE          60 non-null     float64
#  4   Latitude       60 non-null     float64
#  5   Longitude      60 non-null     float64
#  6   Temp 2m        60 non-null     float64
#  7   Dewpoint 2m    60 non-null     float64
#  8   Pressure       60 non-null     float64
#  9   Precipitation  60 non-null     float64
#  10  GHI            60 non-null     float64
#  11  DHI            60 non-null     float64
#  12  BNI            60 non-null     float64
#  13  Location       60 non-null     object
#  14  Date           60 non-null     object
#  15  Time           60 non-null     object
#  16  Date.1         60 non-null     object
# ...

# %%
filtered_data.to_csv("./filtered_data.csv", index = False)

# %%
import matplotlib.pyplot as plt
data_points = filtered_data["Temp 2m"]

# %%
data_points = list(data_points)
plt.figure(figsize = (20, 10))
plt.plot(data_points)
plt.show()

# %%
# temp_data = [round(float(i),2) for i in filtered_data["Temp 2m"]]
import math
temp_data = [math.ceil(float(i)) for i in filtered_data["Temp 2m"]]
print(temp_data)
plt.figure(figsize = (20, 10))
plt.plot(temp_data)
plt.show()
print(len(temp_data))
# Out:
# [12, 11, 12, 12, 11, 10, 11, 12, 12, 11, 11, 11, 11, 10, 10, 12, 12, 10, 11, 10, 11, 10, 10, 10, 10, 11, 11, 12, 12, 12, 11, 9, 10, 11, 11, 11, 11, 11, 11, 12, 12, 12, 13, 12, 11, 11, 11, 11, 11, 10, 11, 10, 11, 12, 12, 11, 11, 10, 10, 10]
# 60

# %%
date_data = [str(i)[:10] for i in filtered_data["Date"]]
date_data
# Out:
# ['30-06-2023',
#  '30-06-2023',
#  '29-06-2023',
#  '29-06-2023',
#  '28-06-2023',
#  '28-06-2023',
#  '27-06-2023',
#  '27-06-2023',
#  '26-06-2023',
#  '26-06-2023',
#  '25-06-2023',
#  '25-06-2023',
#  '24-06-2023',
#  '24-06-2023',
#  '23-06-2023',
#  '23-06-2023',
#  '22-06-2023',
#  '22-06-2023',
#  '21-06-2023',
#  '21-06-2023',
#  '20-06-2023',
#  '20-06-2023',
#  '19-06-2023',
#  '19-06-2023',
#  '18-06-2023',
#  '18-06-2023',
#  '17-06-2023',
#  '17-06-2023',
#  '16-06-2023',
#  '16-06-2023',
#  '15-06-2023',
#  '15-06-2023',
#  '14-06-2023',
#  '14-06-2023',
#  '13-06-2023',
#  '13-06-2023',
#  '12-06-2023',
#  '12-06-2023',
